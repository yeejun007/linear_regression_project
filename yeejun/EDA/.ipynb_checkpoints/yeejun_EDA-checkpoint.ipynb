# %%
import seaborn as sns
import pandas as pd
import matplotlib.pylab as plt
import matplotlib as mpl
from matplotlib import rc
import missingno as msno
import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore')

# matplotlib 한글 사용을 위한 코드
rc('font', family='AppleGothic')

# %%
final_df = pd.read_csv('final_df_03_ols.csv').drop(columns=['Unnamed: 0'])

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 928 entries, 0 to 927
# Data columns (total 26 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  928 non-null    int64
#  1   영화명                 928 non-null    object
#  2   감독                  926 non-null    object
#  3   제작사                 348 non-null    object
#  4   수입사                 585 non-null    object
#  5   배급사                 927 non-null    object
#  6   개봉일                 928 non-null    object
#  7   영화유형                928 non-null    object
#  8   영화형태                928 non-null    object
#  9   국적                  928 non-null    object
#  10  전국스크린수              928 non-null    int64
#  11  전국매출액               928 non-null    int64
#  12  전국관객수               928 non-null    int64
#  13  서울매출액               928 non-null    int64
#  14  서울관객수               928 non-null    int64
# ...

# %%
# final_df['director_power'] = pd.to_numeric(final_df['director_power'])

# %%
# for i, value in enumerate(final_df['director_movie_num']): 
#     if type(value) == type('a'):
#         print(i)

# %%
# final_df = final_df.drop(columns=['id', '제작사', '수입사', '전국매출액', '서울매출액', '서울관객수'], )

# %%
final_df.head(1)
# Out:
#                 영화명     감독             배급사         개봉일  영화유형 영화형태  국적  전국스크린수  \
# 0  어벤져스: 에이지 오브 울트론  조스 웨던  월트디즈니컴퍼니코리아(주)  2015-04-23  개봉영화   장편  미국    1843
#
#       전국관객수  장르        등급  영화구분  expert_rating  \
# 0  10494499  액션  12세이상관람가  일반영화           6.92
#
#                                      starring_actors  running_times  \
# 0  로버트 다우니 주니어(토니 스타크 / 아이언맨), 크리스 헴스워스(토르), 마크 러...            141
#
#    audience_rating  rating_audiences  개봉일_int  director_power  \
# 0         8.612377              5268     2015      17567536.0
#
#   director_movie_num
# 0              1 [1]

# %%
final_df.columns
# Out:
# Index(['영화명', '감독', '배급사', '개봉일', '영화유형', '영화형태', '국적', '전국스크린수', '전국관객수',
#        '장르', '등급', '영화구분', 'expert_rating', 'starring_actors', 'running_times',
#        'audience_rating', 'rating_audiences', '개봉일_int', 'director_power',
#        'director_movie_num'],
#       dtype='object')

# %%
# 전국관객수 타입 int로 바꾸기

# %%
# sns.pairplot(final_df[['expert_rating', 'running_times', 'audience_rating', 'rating_audiences', 'director_power', '전국스크린수', '전국관객수']])
# plt.show()

# %%
for column in final_df.columns:
    for i, value in enumerate(list(final_df[column])):
        if value == 0:
            print('column : {}, index : {}'.format(column, i))
# Out:
# column : expert_rating, index : 47
# column : expert_rating, index : 63
# column : expert_rating, index : 70
# column : expert_rating, index : 79
# column : expert_rating, index : 94
# column : expert_rating, index : 95
# column : expert_rating, index : 138
# column : expert_rating, index : 149
# column : expert_rating, index : 155
# column : expert_rating, index : 159
# column : expert_rating, index : 165
# column : expert_rating, index : 167
# column : expert_rating, index : 168
# column : expert_rating, index : 174
# column : expert_rating, index : 177
# column : expert_rating, index : 179
# column : expert_rating, index : 180
# column : expert_rating, index : 240
# column : expert_rating, index : 248
# column : expert_rating, index : 257
# column : expert_rating, index : 258
# column : expert_rating, index : 260
# column : expert_rating, index : 262
# column : expert_rating, index : 266
# column : expert_rating, index : 270
# column : expert_rating, index : 278
# ...

# %%
# column : running_times, index : 338
# column : running_times, index : 902
# column : audience_rating, index : 168  '맥베스'   -> 2015년걸로 바꿔야함
# column : audience_rating, index : 338 '빅'  -> 셀레니움에서 예외적으로 이거만 검색 버튼을 눌러야 나옴
# column : audience_rating, index : 902
#

# %%
final_df.iloc[534]
# Out:
# id                                                         534
# 영화명                             극장판 에그엔젤 코코밍: 푸르밍과 두근두근 코코밍 세계
# 감독                                                      닛타 노리오
# 제작사                                                        NaN
# 수입사                                                  씨제이이앤엠(주)
# 배급사                                                  씨제이이앤엠(주)
# 개봉일                                                 2017-09-07
# 영화유형                                                      개봉영화
# 영화형태                                                        장편
# 국적                                                          일본
# 전국스크린수                                                     232
# 전국매출액                                               1055895200
# 전국관객수                                                   137052
# 서울매출액                                                230840900
# 서울관객수                                                    29255
# ...

# %%
# number = list(final_df['director_movie_num'])
# index = 0

# def func(power):
#     global index
    
#     if type(number[index]) != type(str('a')):
        
#         index += 1
#         return float('nan')
    
#     index += 1
    
#     try:
#         return (float(power) / float(number[index].split(' ')[0]))
#     except Exception:
#         return power

# %%
# final_df['director_power_02'] = final_df['director_power'].apply(func)

# %%
number_02 = list(final_df['director_power'])

# %%
float(10.0)/float(number[4].split(' ')[0])
# Out:
# 5.0

# %%
final_df['director_power'][784]
# Out:
# nan

# %%
# final_df.iloc[784]

# %%
# number_02

# %%
# for i, value in enumerate(number_02):
#     if value == type(float('nan')):
#         print(i)

# %%
final_df[final_df['director_power'].isna() == True]
# Out:
#               영화명   감독                  배급사         개봉일  영화유형 영화형태  국적  \
# 641      젝스키스 에이틴  NaN  씨제이 씨지브이(CJ CGV)(주)  2018-01-18  개봉영화   장편  한국
# 784  러브 유어셀프 인 서울  NaN  씨제이 씨지브이(CJ CGV)(주)  2019-01-26  개봉영화   장편  한국
#
#      전국스크린수   전국관객수     장르  ...  영화구분 expert_rating  starring_actors  \
# 641      25   50419  다큐멘터리  ...  일반영화           0.0      [국내] 전체 관람가
# 784     224  342366     공연  ...  일반영화           0.0      [국내] 전체 관람가
#
#     running_times  audience_rating  rating_audiences  개봉일_int  director_power  \
# 641           100              0.0                 0     2018             NaN
# 784           113              0.0                 0     2019             NaN
#
#      director_movie_num director_power_02
# 641                 NaN               NaN
# 784                 NaN               NaN
#
# [2 rows x 21 columns]

# %%
# final_df

# %%
# number = list(final_df['director_movie_num'])
# index = 0

# def func(power):
#     global index
    
#     if type(number[index]) != type(str('a')):        
#         index += 1
#         return float('nan')
    
#     try:
#         num = (float(power) / float(number[index].split(' ')[0]))
#         index += 1
#         return num
#     except Exception:
#         return power

# %% [markdown]
# # ================ EDA ================
# - director_movie_num 컬럼 : 해당 row의 감독이 지난 3년간 제작한 영화 갯수

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 928 entries, 0 to 927
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   영화명                 928 non-null    object
#  1   감독                  926 non-null    object
#  2   배급사                 927 non-null    object
#  3   개봉일                 928 non-null    object
#  4   영화유형                928 non-null    object
#  5   영화형태                928 non-null    object
#  6   국적                  928 non-null    object
#  7   전국스크린수              928 non-null    int64
#  8   전국관객수               928 non-null    int64
#  9   장르                  928 non-null    object
#  10  등급                  928 non-null    object
#  11  영화구분                928 non-null    object
#  12  expert_rating       928 non-null    float64
#  13  starring_actors     928 non-null    object
#  14  running_times       928 non-null    int64
# ...

# %%
msno.matrix(final_df);

# %%
a = np.log(final_df['director_power'])

# %%
final_df.hist(figsize=(10,10))
plt.show()

# %%
# 전국 스크린수 : 논문에서 큰 영향을 미친다고 함

# %%
final_df.columns
# Out:
# Index(['영화명', '감독', '배급사', '개봉일', '영화유형', '영화형태', '국적', '전국스크린수', '전국관객수',
#        '장르', '등급', '영화구분', 'expert_rating', 'starring_actors', 'running_times',
#        'audience_rating', 'rating_audiences', '개봉일_int', 'director_power',
#        'director_movie_num'],
#       dtype='object')

# %%
# 배급사 -> 카테고리화 : '몇편 이상인 경우'를 기준으로 대형배급사, 중형배급사, 소형배급사 

plt.figure(figsize=(10, 10))
sns.countplot(x='배급사', data=final_df['배급사'].reset_index().drop(columns=['index']))
plt.show()

# %%
len(final_df['배급사'].unique())
# Out:
# 141

# %%
plt.figure(figsize=(5, 4))
sns.countplot(x='영화유형', data=final_df['영화유형'].reset_index().drop(columns=['index']))
plt.show()

# %%
final_df[final_df['영화형태'] == '옴니버스']
# Out:
#                        영화명             감독            배급사         개봉일  영화유형  \
# 265  무서운 이야기 3 : 화성에서 온 소녀  백승빈,김선,김곡,민규동  롯데쇼핑㈜롯데엔터테인먼트  2016-06-01  개봉영화
#
#      영화형태  국적  전국스크린수  전국관객수      장르        등급  영화구분  expert_rating  \
# 265  옴니버스  한국     317  94926  공포(호러)  15세이상관람가  일반영화            6.0
#
#                starring_actors  running_times  audience_rating  \
# 265  임슬옹(이생), 경수진(수진), 박정민(동근)             94         5.647059
#
#      rating_audiences  개봉일_int  director_power director_movie_num
# 265               136     2016      10301714.0     6 [1, 1, 1, 3]

# %%
# 옴니버스는 너무 작아서 뺸다 

plt.figure(figsize=(5, 4))
sns.countplot(x='영화형태', data=final_df['영화형태'].reset_index().drop(columns=['index']))
plt.show()

# %%
# 카테고리화 -> 미국, 한국, 일본, 기타

plt.figure(figsize=(18, 5))
sns.countplot(x='국적', data=final_df['국적'].reset_index().drop(columns=['index']))
plt.show()

# %%
# 애니메이션이 개봉 갯수는 많은데 관객수를 제일 많이 모은건 액션영화임

plt.figure(figsize=(16, 4))
sns.countplot(x='장르', data=final_df['장르'].reset_index().drop(columns=['index']))
plt.show()

# %%
# 등급은 카테고리화해서 사용

plt.figure(figsize=(10, 4))
sns.countplot(x='등급', data=final_df['등급'].reset_index().drop(columns=['index']))
plt.show()

# %%
# 사용안함?

plt.figure(figsize=(5, 4))
sns.countplot(x='영화구분', data=final_df['영화구분'].reset_index().drop(columns=['index']))
plt.show()
