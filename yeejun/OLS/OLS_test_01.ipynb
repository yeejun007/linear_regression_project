# %%
import seaborn as sns
import matplotlib.pylab as plt
import warnings
warnings.filterwarnings('ignore')

# %%
final_df = pd.read_csv('../final_df_03.csv').drop(columns=['Unnamed: 0'])

# %%
final_df.head(1)
# Out:
#    id               영화명     감독  제작사             수입사             배급사  \
# 0   0  어벤져스: 에이지 오브 울트론  조스 웨던  NaN  월트디즈니컴퍼니코리아(주)  월트디즈니컴퍼니코리아(주)
#
#           개봉일  영화유형 영화형태  국적  ...        등급  영화구분  expert_rating  \
# 0  2015-04-23  개봉영화   장편  미국  ...  12세이상관람가  일반영화           6.92
#
#                                      starring_actors  running_times  \
# 0  로버트 다우니 주니어(토니 스타크 / 아이언맨), 크리스 헴스워스(토르), 마크 러...            141
#
#      audience_rating rating_audiences 개봉일_int director_power  \
# 0  8.612376613515565             5268    2015     17567536.0
#
#   director_movie_num
# 0              1 [1]
#
# [1 rows x 26 columns]

# %%
# sns.pairplot(final_df[])

# %%
final_df['director_power'] = pd.to_numeric(final_df['director_power'])

# %%
# for i, value in enumerate(final_df['expert_rating']): 
#     if value == '-':
#         final_df['expert_rating'][i] = 0

# %%
for i, value in enumerate(final_df['director_power']): 
    if type(value) == type('a'):
        print(i)

# %%
# for i, value in enumerate(final_df['running_times']):
#     final_df['running_times'][i] = final_df['running_times'][i][:-1]

# %%
# final_df['running_times'][862] = '132'

# %%
# final_df.iloc[862]

# %%
final_df.rename(columns={'director_moive_num' : 'director_movie_num'}, inplace=True)

# %%
sns.pairplot(final_df[['expert_rating', 'running_times', 'audience_rating', 'rating_audiences', 'director_power']])
plt.show()

# %%
type(final_df.iloc[168]['rating_audiences'])
# Out:
# int

# %%
for i, value in enumerate()

# %%
# 이거 만드는 중이었음

# final_df['director_movie_total'] = final_df['director_movie_num'].apply(lambda num : num[:1])

# %%
final_df.to_csv('final_df_03_ols.csv', mode='w')
