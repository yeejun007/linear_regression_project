# %%
import seaborn as sns
import pandas as pd
import re
import matplotlib as mpl
from matplotlib import rc
import missingno as msno
import warnings
import datetime
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

# matplotlib 한글 사용을 위한 코드
rc('font', family='AppleGothic')

# %%
# X_train = pd.read_csv('X_train_08_1.csv').drop(columns='Unnamed: 0')
# y_train = pd.read_csv('y_train_08_1.csv').drop(columns='Unnamed: 0')
# X_test = pd.read_csv('X_test_08_1.csv').drop(columns='Unnamed: 0')
# y_test = pd.read_csv('y_test_08_1.csv').drop(columns='Unnamed: 0')

# %%
X_train = pd.read_csv('X_train_09.csv').drop(columns='Unnamed: 0')
y_train = pd.read_csv('y_train_09.csv').drop(columns='Unnamed: 0')
X_test = pd.read_csv('X_test_09.csv').drop(columns='Unnamed: 0')
y_test = pd.read_csv('y_test_09.csv').drop(columns='Unnamed: 0')

# %%
total_df = pd.concat([X_train, y_train], axis=1)
total_df.columns
# Out:
# Index(['title', 'director', 'distributor', 'distributor_group', 'release_date',
#        'release_season', 'nation', 'screen', 'genre', 'rate', 'expert_rating',
#        'starring_actors', 'running_times', 'audience_rating',
#        'rating_audiences', 'director_power', 'sequel', 'original',
#        'actor_power', 'before_news', 'after_news', 'aud_nationwide',
#        'log_aud'],
#       dtype='object')

# %%
total_df.head(1)
# Out:
#      title director     distributor distributor_group release_date  \
# 0  인사이드 아웃    피트 닥터  월트디즈니컴퍼니코리아(주)                 B     7/9/2015
#
#   release_season nation  screen  genre   rate  ...  audience_rating  \
# 0         summer     미국     777  애니메이션  전체관람가  ...         9.113006
#
#   rating_audiences  director_power  sequel  original  actor_power  \
# 0              938       4968687.0       0         0     14906061
#
#    before_news  after_news  aud_nationwide    log_aud
# 0      15150.0       384.0         4968687  15.418666
#
# [1 rows x 23 columns]

# %%
# X_train = total_df.drop(columns=['rev_nationwide', 'rev_seoul', 'rev_seoul.1', 'type', 'release', 'form', 'realease_year', 'director_movie_num', 'aud_nationwide'])
# y_train = total_df['aud_nationwide']

# %%
# from sklearn.model_selection import train_test_split

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# len(X_train), len(y_train), len(X_test), len(y_test)

# %%
len(X_train.columns)
# Out:
# 21

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              740 non-null    object
#  1   director           740 non-null    object
#  2   distributor        740 non-null    object
#  3   distributor_group  740 non-null    object
#  4   release_date       740 non-null    object
#  5   release_season     740 non-null    object
#  6   nation             740 non-null    object
#  7   screen             740 non-null    int64
#  8   genre              740 non-null    object
#  9   rate               740 non-null    object
#  10  expert_rating      740 non-null    float64
#  11  starring_actors    740 non-null    object
#  12  running_times      740 non-null    int64
#  13  audience_rating    740 non-null    float64
#  14  rating_audiences   740 non-null    int64
#  15  director_power     740 non-null    float64
#  16  sequel             740 non-null    int64
#  17  original           740 non-null    int64
#  18  actor_power        740 non-null    int64
#  19  before_news        740 non-null    float64
#  20  after_news         740 non-null    float64
# dtypes: float64(5), int64(6), object(10)
# memory usage: 121.5+ KB

# %%
df = pd.concat([X_train, y_train], axis=1)

# %%
df = df.reset_index().drop(columns='index')

# %%
import statsmodels.api as sm

model = sm.OLS.from_formula("aud_nationwide ~ distributor_group + release_season + nation + genre + rate + C(sequel) + C(original) + screen + expert_rating + audience_rating + running_times + rating_audiences + director_power + actor_power", data=df)
result = model.fit()

# %%
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         aud_nationwide   R-squared:                       0.751
# Model:                            OLS   Adj. R-squared:                  0.738
# Method:                 Least Squares   F-statistic:                     58.79
# Date:                Thu, 02 Apr 2020   Prob (F-statistic):          5.89e-186
# Time:                        10:43:36   Log-Likelihood:                -11282.
# No. Observations:                 740   AIC:                         2.264e+04
# Df Residuals:                
# expert_rating             3.176e+04    2.3e+04      1.383      0.167   -1.33e+04    7.69e+04
# audience_rating             6.2e+04   2.99e+04      2.073      0.039    3289.573    1.21e+05
# running_times            -4871.0411   2814.920     -1.730      0.084   -1.04e+04     655.615
# rating_audiences           414.7672     43.394      9.558      0.000     329.569     499.966
# director_power               0.0058      0.004      1.461      0.144      -0.002       0.014
# actor_power                  0.0026      0.000      7.379      0.000       0.002       0.003
# ==============================================================================
# Omnibus:                      528.785   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            13580.735
# Skew:                           2.869   Prob(JB):                         0.00
# Kurtosis:                      23.188   Cond. No.                     4.70e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.7e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
plt.plot(y_train['aud_nationwide'].sort_values().reset_index(drop = True))
plt.show()

# %%
plt.plot(np.log(y_train['aud_nationwide'].sort_values().reset_index(drop = True)))
plt.show()

# %%
df0_1 = df0.reset_index()

# %% [markdown]
# # model0
# - 영화개봉 전, 후 뉴스기사 컬럼 사용
# - 영화 개봉 전 : before_news
# - 영화 개봉 후 : after_news
# - 총 15개 독립변수 사용
# - 종속변수에 Log 씌움

# %%
df0 = df.copy()

# %%
plt.figure(figsize=(12,6))
plt.subplot(121)
sns.scatterplot(x="before_news", y="aud_nationwide", data=df0)
plt.subplot(122)
sns.scatterplot(x="after_news", y="aud_nationwide", data=df0)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 8))

index = list(df0_1['index'])
x_cords = list(df0_1['before_news'])
y_cords = list(df0_1['aud_nationwide'])

for i, index in enumerate(index):
    x = x_cords[i]
    y = y_cords[i]
    plt.scatter(x, y, marker='o', color='blue')
    plt.text(x + 0.4, y + 0.4, str(index), fontsize=9)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 8))

index = list(df0_1['index'])
x_cords = list(df0_1['after_news'])
y_cords = list(df0_1['aud_nationwide'])

for i, index in enumerate(index):
    x = x_cords[i]
    y = y_cords[i]
    plt.scatter(x, y, marker='o', color='blue')
    plt.text(x + 0.4, y + 0.4, str(index), fontsize=9)
plt.show()

# %%
len(df)
# Out:
# 740

# %%
list(df0_1[df0_1['distributor_group'] == 'C']['distributor'])
# Out:
# ['(재)CBS,(주)영화사 안다미로',
#  '(주)쇼박스',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)쇼박스',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)홈초이스',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)쇼박스',
#  '(주)쇼박스',
#  '(주)쇼박스',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)쇼박스',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)쇼박스',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)쇼박스',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)쇼박스',
#  '(주)쇼박스',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)쇼박스',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)쇼박스',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(재)CBS',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)쇼박스',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)쇼박스',
#  '(주)아이코닉스',
#  '(주)쇼박스',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)홈초이스',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)쇼박스',
#  '(주)쇼박스',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)쇼박스',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)쇼박스',
#  '(주)쇼박스',
#  '(주)쇼박스',
#  '(주)쇼박스',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)넥스트엔터테인먼트월드(NEW)',
#  '(주)쇼박스',
#  '(주)쇼박스',
#  '(주)쇼박스',
#  '(주)넥스트엔터테인먼트월드(NEW)']

# %%
df0_1.iloc[309]
# Out:
# index                               309
# title                                 팬
# director                          조 라이트
# distributor               워너브러더스 코리아(주)
# distributor_group                     B
# release_date                  10/8/2015
# release_season                   autumn
# nation                               미국
# screen                              428
# genre                               판타지
# rate                              전체관람가
# expert_rating                         5
# starring_actors      휴 잭맨,가렛 헤드룬드,루니 마라
# running_times                       111
# audience_rating                 8.15789
# rating_audiences                    133
# director_power                   552590
# sequel                                1
# original                              0
# actor_power                    82048452
# before_news                 5.73475e+06
# after_news                        17083
# aud_nationwide                   185960
# log_aud                         12.1333
# Name: 309, dtype: object

# %%
# df에서 title을 제외하고 15개의 독립변수 사용

feature_names = ['screen', 'expert_rating', 'audience_rating', 'running_times', 'rating_audiences', 'director_power', 'actor_power', 'before_news', 'after_news']
feature_names = ["scale({})".format(name) for name in feature_names] + ['distributor_group', 'release_season', 'nation', 'genre', 'rate', 'C(original)']
model0 = sm.OLS.from_formula("log_aud ~" + "+".join(feature_names), data=df0)
result0 = model0.fit()
print(result0.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                log_aud   R-squared:                       0.783
# Model:                            OLS   Adj. R-squared:                  0.771
# Method:                 Least Squares   F-statistic:                     68.40
# Date:                Thu, 02 Apr 2020   Prob (F-statistic):          8.22e-206
# Time:                        11:16:12   Log-Likelihood:                -782.52
# No. Observations:                 740   AIC:                             1641.
# Df Residuals:                     702   BIC:                             1816.
# Df Model:                          37
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   12
# %%
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df0)):
    df_train = df0.iloc[idx_train]
    df_test = df0.iloc[idx_test]
    
    model = sm.OLS.from_formula("log_aud ~" + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred =  result.predict(df_test[['screen', 'expert_rating', 'audience_rating', 'running_times', 'rating_audiences', 'director_power', 'actor_power', 'before_news', 'after_news', 'distributor_group', 'release_season', 'nation', 'genre', 'rate', 'original']])
    rss = ((df_test['log_aud'] - pred) ** 2).sum()
    tss = ((df_test['log_aud'] - df_test['log_aud'].mean()) ** 2).sum()
    rsquared = 1 - rss/tss

    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
# Out:
# 학습 R2 = 0.78107830, 검증 R2 = 0.78716375
# 학습 R2 = 0.78335910, 검증 R2 = 0.75653768
# 학습 R2 = 0.78521791, 검증 R2 = 0.64987127
# 학습 R2 = 0.78714506, 검증 R2 = 0.73253040
# 학습 R2 = 0.78352187, 검증 R2 = 0.76016357
# 학습 R2 = 0.78669414, 검증 R2 = 0.72586459
# 학습 R2 = 0.78677117, 검증 R2 = 0.71516694
# 학습 R2 = 0.78512876, 검증 R2 = 0.74644347
# 학습 R2 = 0.78146339, 검증 R2 = 0.78012091
# 학습 R2 = 0.78606747, 검증 R2 = 0.73574778

# %%
fig = plt.figure(figsize=(12, 80))
sm.graphics.plot_partregress_grid(result0, fig=fig)
fig.suptitle("")
plt.show()

# %% [markdown]
# # model1
# - 장르의 구분 조정

# %% [markdown]
# # model2
# - sequel컬럼 제거

# %%
df.columns
# Out:
# Index(['title', 'director', 'distributor', 'distributor_group', 'release_date',
#        'release_season', 'nation', 'screen', 'genre', 'rate', 'expert_rating',
#        'starring_actors', 'running_times', 'audience_rating',
#        'rating_audiences', 'director_power', 'sequel', 'original',
#        'actor_power', 'before_news', 'after_news', 'aud_nationwide',
#        'log_aud'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 23

# %%
# df에서 title을 제외하고 13개의 독립변수 사용

feature_names = ['screen', 'expert_rating', 'audience_rating', 'running_times', 'rating_audiences', 'director_power', 'actor_power']
feature_names = ["scale({})".format(name) for name in feature_names] + ['distributor_group', 'release_season', 'nation', 'genre', 'rate', 'C(original)']
model2 = sm.OLS.from_formula("log_aud ~" + "+".join(feature_names), data=df)
result2 = model2.fit()
print(result2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                log_aud   R-squared:                       0.782
# Model:                            OLS   Adj. R-squared:                  0.772
# Method:                 Least Squares   F-statistic:                     72.29
# Date:                Thu, 02 Apr 2020   Prob (F-statistic):          2.60e-207
# Time:                        10:43:44   Log-Likelihood:                -783.40
# No. Observations:                 740   AIC:                             1639.
# Df Residuals:                     704   BIC:                             1805.
# Df Model:                          35
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   12.5386      0.235     53.380      0.000      12.077      13.000
# distributor_group[T.B]      -0.0266      0.082     -0.325      0.745      -0.187       0.134
# distributor_group[T.C]      -0.0658      0.098     -0.671      0.502      -0.258       0.127
# distributor_group[T.D]      -0.4703      0.084     -5.591      0.000      -0.635      -0.305
# release_season[T.spring]    -0.0055      0.079     -0.070      0.944      -0.160       0.149
# release_season[T.summer]     0.1115      0.077      1.453      0.147      -0.039       0.262
# release_season[T.winter]     0.1473      0.074      1.978      0.048       0.001       0.293
# nation[T.미국]                 0.1363      0.126      1.080      0.280      -0.111       0.384
# nation[T.영국]                 0.1158      0.175      0.661      0.509      -0.228       0.460
# nation[T.일본]                 0.1921      0.149      1.289      0.198      -0.100       0.485
# nation[T.프랑스]               -0.2035      0.234     -0.871      0.384      -0.662       0.255
# nation[T.한국]                 0.3335      0.133      2.511      0.012       0.073       0.594
# genre[T.공포]                  0.4125      0.226      1.824      0.069      -0.031       0.856
# genre[T.다큐멘터리]               0.3845      0.272      1.415      0.158      -0.149       0.918
# genre[T.드라마]                 0.0941      0.199      0.472      0.637      -0.297       0.485
# genre[T.멜로/로맨스]              0.3121      0.236      1.323      0.186      -0.151       0.775
# genre[T.미스터리]                0.1681      0.242      0.693      0.488      -0.308       0.644
# genre[T.범죄]                  0.1754      0.221      0.794      0.427      -0.258       0.609
# genre[T.사극]                  0.4469      0.283      1.580      0.114      -0.108       1.002
# genre[T.스릴러]                 0.2132      0.227      0.941      0.347      -0.232       0.658
# genre[T.애니메이션]               0.4219      0.228      1.852      0.065      -0.025       0.869
# genre[T.액션]                  0.3213      0.197      1.633      0.103      -0.065       0.708
# genre[T.어드벤처]                0.4407      0.251      1.756      0.079      -0.052       0.933
# genre[T.코미디]                 0.2332      0.216      1.078      0.281      -0.191       0.658
# genre[T.판타지]                -0.0407      0.260     -0.157      0.876      -0.551       0.470
# rate[T.15세이상관람가]            -0.0618      0.075     -0.827      0.408      -0.208       0.085
# rate[T.전체관람가]               -0.2182      0.118     -1.849      0.065      -0.450       0.013
# rate[T.청소년관람불가]             -0.0985      0.102     -0.966      0.334      -0.299       0.102
# C(original)[T.1]            -0.1204      0.065     -1.858      0.064      -0.248       0.007
# scale(screen)                1.0554      0.046     22.914      0.000       0.965       1.146
# scale(expert_rating)         0.0988      0.032      3.078      0.002       0.036       0.162
# scale(audience_rating)       0.1208      0.029      4.203      0.000       0.064       0.177
# scale(running_times)         0.0336      0.039      0.871      0.384      -0.042       0.109
# scale(rating_audiences)      0.1180      0.043      2.729      0.007       0.033       0.203
# scale(director_power)       -0.1572      0.037     -4.216      0.000      -0.230      -0.084
# scale(actor_power)           0.0869      0.035      2.475      0.014       0.018       0.156
# ==============================================================================
# Omnibus:                        5.580   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.061   Jarque-Bera (JB):                5.442
# Skew:                           0.188   Prob(JB):                       0.0658
# Kurtosis:                       3.189   Cond. No.                         47.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# release_season

# print(result2.t_test("Intercept = distributor_group[T.B]"))

# %%
# model2의 테스트 R
 
pred =  result2.predict(X_test[['screen', 'expert_rating', 'audience_rating', 'running_times', 'rating_audiences', 'director_power', 'actor_power', 'distributor_group', 'release_season', 'nation', 'genre', 'rate', 'original']])
rss = ((y_test['log_aud'] - pred) ** 2).sum()
tss = ((y_test['log_aud'] - y_test['log_aud'].mean()) ** 2).sum()
rsquared = 1 - rss/tss
rsquared
# Out:
# 0.7473477125213485

# %%
## Cook's distance

sm.graphics.plot_leverage_resid2(result2)
plt.show()

# %%
sm.graphics.influence_plot(result2, plot_alpha=0.3)
plt.show()

# %%
df.iloc[191]
# Out:
# title                     크레이지 리치 아시안
# director                          존 추
# distributor             워너브러더스 코리아(주)
# distributor_group                   B
# release_date               10/25/2018
# release_season                 autumn
# nation                             미국
# screen                            531
# genre                          멜로/로맨스
# rate                         12세이상관람가
# expert_rating                     6.5
# starring_actors      콘스탄스 우,헨리 골딩,양자경
# running_times                     120
# audience_rating                7.9064
# rating_audiences                  203
# director_power            8.21044e+06
# sequel                              0
# original                            1
# actor_power                   3663164
# before_news                      1224
# after_news                        279
# aud_nationwide                 154297
# log_aud                       11.9466
# Name: 191, dtype: object

# %%
# plt.scatter(df['audience_rating'], df['aud_nationwide'])
# plt.xlim((6, 10))

# %% [markdown]
# # model3
# - 아웃라이어 제거:
#     - 어벤져스(마블) 576
#     - 어벤져스(마블) 361
#     - 캡틴 아메리카(마블) 398

# %%
df3 = df.copy()
len(df3.columns)
# Out:
# 23

# %%
len(df3)
# Out:
# 740

# %%
df3.drop(index=[576, 398, 361], inplace=True)

# %%
len(df3)
# Out:
# 737

# %%
# df에서 title을 제외하고 14개의 독립변수 사용

feature_names = ['screen', 'expert_rating', 'audience_rating', 'running_times', 'rating_audiences', 'director_power', 'actor_power']
feature_names = ["scale({})".format(name) for name in feature_names] + ['distributor_group', 'release_season', 'nation', 'genre', 'rate', 'C(original)']
model3 = sm.OLS.from_formula("np.log(aud_nationwide) ~" + "+".join(feature_names), data=df3)
result3 = model3.fit()
print(result3.summary())
# Out:
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     np.log(aud_nationwide)   R-squared:                       0.786
# Model:                                OLS   Adj. R-squared:                  0.776
# Method:                     Least Squares   F-statistic:                     73.71
# Date:                    Thu, 02 Apr 2020   Prob (F-statistic):          3.82e-209
# Time:                            10:44:19   Log-Likelihood:                -766.89
# No. Observations:                     737   AIC:                             1606.
# Df Residuals:                         701   BIC:                             1771.
# Df Model:                              35
# Covariance Type:                nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   12
8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# model3의 테스트 R
 
pred =  result3.predict(X_test[['screen', 'expert_rating', 'audience_rating', 'running_times', 'rating_audiences', 'director_power', 'actor_power', 'distributor_group', 'release_season', 'nation', 'genre', 'rate', 'original']])
rss = ((y_test['log_aud'] - pred) ** 2).sum()
tss = ((y_test['log_aud'] - y_test['log_aud'].mean()) ** 2).sum()
rsquared = 1 - rss/tss
rsquared
# Out:
# 0.7509881440858145

# %%
# 시간을 카테고리화 하는 기준에 대한 근거 -> 나중에 생각
# 60~100, 100~140, 140~160

# plt.figure(figsize=(24, 12))
# sns.barplot(x="running_times", y="aud_nationwide", data=df3)
# plt.show()

# %%
# df3[df3['running_times'] > 80][df3[df3['running_times'] > 80]['running_times'] <= 100]

# %% [markdown]
# # model4
# - running_time 컬럼을 카테고리화 시키기
# - df3에서 러닝타임을 카테고리화시켜서 df4를 만든다
# - 60 ~ 100 : A
# - 100 ~ 140 : B
# - 140 ~ : C

# %%
sns.scatterplot(x="running_times", y="aud_nationwide", data=df3)
plt.show()

# %%
df4 = df3.copy()

# %%
def R_func(time):
    if time < 100:
        return 'A'
    elif time >= 100 and time < 140:
        return 'B'
    else:
        return 'C'

# %%
df4['CAT_running_times'] = df3['running_times'].apply(R_func)

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x="CAT_running_times", y="aud_nationwide", data=df4)
plt.show()

# %%
# df4 

feature_names = ['screen', 'expert_rating', 'audience_rating', 'rating_audiences', 'director_power', 'actor_power']
feature_names = ["scale({})".format(name) for name in feature_names] + ['distributor_group', 'release_season', 'nation', 'genre', 'rate', 'C(original)', 'CAT_running_times']
model4 = sm.OLS.from_formula("log_aud ~" + "+".join(feature_names), data=df4)
result4 = model4.fit()
print(result4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                log_aud   R-squared:                       0.791
# Model:                            OLS   Adj. R-squared:                  0.780
# Method:                 Least Squares   F-statistic:                     73.69
# Date:                Thu, 02 Apr 2020   Prob (F-statistic):          1.15e-211
# Time:                        10:44:29   Log-Likelihood:                -758.39
# No. Observations:                 737   AIC:                             1591.
# Df Residuals:                     700   BIC:                             1761.
# Df Model:                          36
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   12.4197      0.238     52.183      0.000      11.952      12.887
# distributor_group[T.B]      -0.0241      0.079     -0.304      0.761      -0.180       0.132
# distributor_group[T.C]      -0.1273      0.096     -1.327      0.185      -0.316       0.061
# distributor_group[T.D]      -0.4602      0.082     -5.622      0.000      -0.621      -0.299
# release_season[T.spring]    -0.0087      0.077     -0.114      0.910      -0.160       0.143
# release_season[T.summer]     0.0482      0.075      0.641      0.522      -0.099       0.196
# release_season[T.winter]     0.1098      0.072      1.515      0.130      -0.032       0.252
# nation[T.미국]                 0.1155      0.123      0.940      0.347      -0.126       0.357
# nation[T.영국]                 0.1208      0.170      0.710      0.478      -0.213       0.455
# nation[T.일본]                 0.1222      0.146      0.836      0.404      -0.165       0.409
# nation[T.프랑스]               -0.2473      0.227     -1.088      0.277      -0.694       0.199
# nation[T.한국]                 0.3377      0.129      2.628      0.009       0.085       0.590
# genre[T.공포]                  0.4456      0.222      2.009      0.045       0.010       0.881
# genre[T.다큐멘터리]               0.2910      0.265      1.099      0.272      -0.229       0.811
# genre[T.드라마]                 0.0465      0.194      0.240      0.811      -0.334       0.427
# genre[T.멜로/로맨스]              0.2570      0.229      1.120      0.263      -0.194       0.707
# genre[T.미스터리]                0.1475      0.236      0.625      0.532      -0.316       0.611
# genre[T.범죄]                  0.1451      0.215      0.676      0.499      -0.276       0.567
# genre[T.사극]                  0.3707      0.275      1.350      0.178      -0.169       0.910
# genre[T.스릴러]                 0.2713      0.220      1.231      0.219      -0.161       0.704
# genre[T.애니메이션]               0.3831      0.224      1.709      0.088      -0.057       0.823
# genre[T.액션]                  0.2926      0.192      1.527      0.127      -0.084       0.669
# genre[T.어드벤처]                0.3922      0.243      1.611      0.108      -0.086       0.870
# genre[T.코미디]                 0.1925      0.210      0.915      0.361      -0.221       0.606
# genre[T.판타지]                -0.1658      0.253     -0.655      0.513      -0.663       0.331
# rate[T.15세이상관람가]            -0.0840      0.073     -1.153      0.249      -0.227       0.059
# rate[T.전체관람가]               -0.1462      0.115     -1.275      0.203      -0.371       0.079
# rate[T.청소년관람불가]             -0.1244      0.099     -1.254      0.210      -0.319       0.070
# C(original)[T.1]            -0.0988      0.063     -1.567      0.118      -0.223       0.025
# CAT_running_times[T.B]       0.2612      0.081      3.228      0.001       0.102       0.420
# CAT_running_times[T.C]      -0.0907      0.148     -0.611      0.541      -0.382       0.201
# scale(screen)                0.9209      0.046     19.919      0.000       0.830       1.012
# scale(expert_rating)         0.0821      0.031      2.674      0.008       0.022       0.142
# scale(audience_rating)       0.1090      0.028      3.899      0.000       0.054       0.164
# scale(rating_audiences)      0.1737      0.037      4.650      0.000       0.100       0.247
# scale(director_power)        0.0460      0.034      1.363      0.173      -0.020       0.112
# scale(actor_power)           0.0506      0.035      1.467      0.143      -0.017       0.118
# ==============================================================================
# Omnibus:                        0.978   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.613   Jarque-Bera (JB):                0.838
# Skew:                           0.070   Prob(JB):                        0.658
# Kurtosis:                       3.088   Cond. No.                         46.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X_test_CAT_r = X_test.copy()

# %%
X_test_CAT_r['CAT_running_times'] = X_test['running_times'].apply(R_func)

# %%
# model4의 테스트 R
 
pred =  result4.predict(X_test_CAT_r[['screen', 'expert_rating', 'audience_rating', 'CAT_running_times', 'rating_audiences', 'director_power', 'actor_power', 'distributor_group', 'release_season', 'nation', 'genre', 'rate', 'original']])
rss = ((y_test['log_aud'] - pred) ** 2).sum()
tss = ((y_test['log_aud'] - y_test['log_aud'].mean()) ** 2).sum()
rsquared = 1 - rss/tss
rsquared
# Out:
# 0.7629522992082522

# %% [markdown]
# # model5
# - expert_rating 카테고리화

# %%
sns.scatterplot(x="expert_rating", y="aud_nationwide", data=df4)
plt.show()

# %%
df5 = df4.copy()

# %%
def EX_func(rating):
    if rating <= 3:
        return 'A'
    elif rating > 3 and rating <= 7:
        return 'B'
    else:
        return 'C'

# %%
df5['CAT_expert_rating'] = df4['expert_rating'].apply(EX_func)

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x="CAT_expert_rating", y="aud_nationwide", data=df5)
plt.show()

# %%
# df5 

feature_names = ['screen', 'audience_rating', 'rating_audiences', 'director_power', 'actor_power']
feature_names = ["scale({})".format(name) for name in feature_names] + ['distributor_group', 'release_season', 'nation', 'genre', 'rate', 'C(original)', 'CAT_running_times', 'CAT_expert_rating']
model5 = sm.OLS.from_formula("log_aud ~" + "+".join(feature_names), data=df5)
result5 = model5.fit()
print(result5.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                log_aud   R-squared:                       0.794
# Model:                            OLS   Adj. R-squared:                  0.784
# Method:                 Least Squares   F-statistic:                     72.99
# Date:                Thu, 02 Apr 2020   Prob (F-statistic):          4.96e-213
# Time:                        10:44:57   Log-Likelihood:                -752.73
# No. Observations:                 737   AIC:                             1581.
# Df Residuals:                     699   BIC:                             1756.
# Df Model:                          37
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   12.2099      0.250     48.750      0.000      11.718      12.702
# distributor_group[T.B]      -0.0313      0.079     -0.398      0.691      -0.186       0.123
# distributor_group[T.C]      -0.1367      0.095     -1.435      0.152      -0.324       0.050
# distributor_group[T.D]      -0.4609      0.081     -5.672      0.000      -0.620      -0.301
# release_season[T.spring]    -0.0080      0.076     -0.105      0.916      -0.158       0.142
# release_season[T.summer]     0.0536      0.075      0.718      0.473      -0.093       0.200
# release_season[T.winter]     0.1214      0.072      1.685      0.093      -0.020       0.263
# nation[T.미국]                 0.1149      0.122      0.942      0.347      -0.125       0.354
# nation[T.영국]                 0.0955      0.169      0.564      0.573      -0.237       0.428
# nation[T.일본]                 0.1111      0.145      0.765      0.445      -0.174       0.396
# nation[T.프랑스]               -0.2709      0.226     -1.199      0.231      -0.714       0.173
# nation[T.한국]                 0.3434      0.128      2.693      0.007       0.093       0.594
# genre[T.공포]                  0.4582      0.220      2.079      0.038       0.026       0.891
# genre[T.다큐멘터리]               0.3699      0.263      1.408      0.160      -0.146       0.886
# genre[T.드라마]                 0.0952      0.193      0.494      0.621      -0.283       0.473
# genre[T.멜로/로맨스]              0.3363      0.229      1.471      0.142      -0.113       0.785
# genre[T.미스터리]                0.2190      0.235      0.933      0.351      -0.242       0.680
# genre[T.범죄]                  0.2124      0.214      0.992      0.322      -0.208       0.633
# genre[T.사극]                  0.4129      0.273      1.512      0.131      -0.123       0.949
# genre[T.스릴러]                 0.3469      0.219      1.581      0.114      -0.084       0.778
# genre[T.애니메이션]               0.4075      0.223      1.829      0.068      -0.030       0.845
# genre[T.액션]                  0.3394      0.191      1.779      0.076      -0.035       0.714
# genre[T.어드벤처]                0.4160      0.242      1.720      0.086      -0.059       0.891
# genre[T.코미디]                 0.2623      0.210      1.250      0.212      -0.150       0.674
# genre[T.판타지]                -0.0856      0.253     -0.339      0.735      -0.582       0.411
# rate[T.15세이상관람가]            -0.0831      0.072     -1.148      0.251      -0.225       0.059
# rate[T.전체관람가]               -0.1358      0.114     -1.192      0.234      -0.360       0.088
# rate[T.청소년관람불가]             -0.1480      0.099     -1.499      0.134      -0.342       0.046
# C(original)[T.1]            -0.0760      0.063     -1.206      0.228      -0.200       0.048
# CAT_running_times[T.B]       0.2366      0.081      2.930      0.004       0.078       0.395
# CAT_running_times[T.C]      -0.1673      0.150     -1.117      0.265      -0.461       0.127
# CAT_expert_rating[T.B]       0.1432      0.096      1.493      0.136      -0.045       0.331
# CAT_expert_rating[T.C]       0.4399      0.118      3.728      0.000       0.208       0.672
# scale(screen)                0.9375      0.046     20.287      0.000       0.847       1.028
# scale(audience_rating)       0.1047      0.028      3.766      0.000       0.050       0.159
# scale(rating_audiences)      0.1583      0.037      4.223      0.000       0.085       0.232
# scale(director_power)        0.0423      0.033      1.262      0.207      -0.023       0.108
# scale(actor_power)           0.0545      0.034      1.588      0.113      -0.013       0.122
# ==============================================================================
# Omnibus:                        1.033   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.597   Jarque-Bera (JB):                0.894
# Skew:                           0.074   Prob(JB):                        0.640
# Kurtosis:                       3.086   Cond. No.                         50.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X_test_CAT_Ex = X_test_CAT_r.copy()

# %%
X_test_CAT_Ex['CAT_expert_rating'] = X_test['expert_rating'].apply(EX_func)

# %%
# model5의 테스트 R
 
pred =  result5.predict(X_test_CAT_Ex[['screen', 'CAT_expert_rating', 'audience_rating', 'CAT_running_times', 'rating_audiences', 'director_power', 'actor_power', 'distributor_group', 'release_season', 'nation', 'genre', 'rate', 'original']])
rss = ((y_test['log_aud'] - pred) ** 2).sum()
tss = ((y_test['log_aud'] - y_test['log_aud'].mean()) ** 2).sum()
rsquared = 1 - rss/tss
rsquared
# Out:
# 0.7622293542174263

# %%
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df5)):
    df_train = df5.iloc[idx_train]
    df_test = df5.iloc[idx_test]
    
    model = sm.OLS.from_formula("log_aud ~" + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred =  result.predict(df_test[['screen', 'CAT_expert_rating', 'audience_rating', 'CAT_running_times', 'rating_audiences', 'director_power', 'actor_power', 'distributor_group', 'release_season', 'nation', 'genre', 'rate', 'original']])
    rss = ((df_test['log_aud'] - pred) ** 2).sum()
    tss = ((df_test['log_aud'] - df_test['log_aud'].mean()) ** 2).sum()
    rsquared = 1 - rss/tss

    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
# Out:
# 학습 R2 = 0.79335122, 검증 R2 = 0.78036786
# 학습 R2 = 0.79809452, 검증 R2 = 0.73130057
# 학습 R2 = 0.79638205, 검증 R2 = 0.75752705
# 학습 R2 = 0.79528544, 검증 R2 = 0.76947935
# 학습 R2 = 0.79905499, 검증 R2 = 0.73813674
# 학습 R2 = 0.79831880, 검증 R2 = 0.73157072
# 학습 R2 = 0.79628335, 검증 R2 = 0.74008646
# 학습 R2 = 0.79283142, 검증 R2 = 0.78798685
# 학습 R2 = 0.79067268, 검증 R2 = 0.80671174
# 학습 R2 = 0.79722385, 검증 R2 = 0.75773444

# %% [markdown]
# # model6
# - audience_rating 카테고리화

# %%
sns.scatterplot(x="audience_rating", y="aud_nationwide", data=df5)
plt.show()

# %%
df6 = df5.copy()

# %%
def AU_func(rating):
    if rating <= 4:
        return 'A'
    elif rating > 4 and rating <= 8:
        return 'B'
    else:
        return 'C'

# %%
df6['CAT_audience_rating'] = df5['audience_rating'].apply(AU_func)

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x="CAT_audience_rating", y="aud_nationwide", data=df6)
plt.show()

# %%
# df6

feature_names = ['screen', 'rating_audiences', 'director_power', 'actor_power']
feature_names = ["scale({})".format(name) for name in feature_names] + ['distributor_group', 'release_season', 'nation', 'genre', 'rate', 'C(original)', 'CAT_running_times', 'CAT_expert_rating', 'CAT_audience_rating']
model6 = sm.OLS.from_formula("log_aud ~" + "+".join(feature_names), data=df6)
result6 = model6.fit()
print(result6.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                log_aud   R-squared:                       0.799
# Model:                            OLS   Adj. R-squared:                  0.788
# Method:                 Least Squares   F-statistic:                     72.97
# Date:                Thu, 02 Apr 2020   Prob (F-statistic):          2.10e-215
# Time:                        10:45:33   Log-Likelihood:                -744.58
# No. Observations:                 737   AIC:                             1567.
# Df Residuals:                     698   BIC:                             1747.
# Df Model:                          38
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   12.3075      0.306     40.258      0.000      11.707      12.908
# distributor_group[T.B]      -0.0424      0.078     -0.543      0.587      -0.196       0.111
# distributor_group[T.C]      -0.1396      0.094     -1.480      0.139      -0.325       0.046
# distributor_group[T.D]      -0.4457      0.080     -5.553      0.000      -0.603      -0.288
# release_season[T.spring]     0.0230      0.076      0.303      0.762      -0.126       0.172
# release_season[T.summer]     0.0790      0.074      1.065      0.287      -0.067       0.225
# release_season[T.winter]     0.1551      0.072      2.169      0.030       0.015       0.296
# nation[T.미국]                 0.0861      0.121      0.712      0.476      -0.151       0.323
# nation[T.영국]                 0.1063      0.168      0.634      0.526      -0.223       0.435
# nation[T.일본]                 0.0554      0.144      0.385      0.701      -0.228       0.338
# nation[T.프랑스]               -0.2224      0.224     -0.994      0.321      -0.662       0.217
# nation[T.한국]                 0.3242      0.126      2.569      0.010       0.076       0.572
# genre[T.공포]                  0.3827      0.218      1.753      0.080      -0.046       0.811
# genre[T.다큐멘터리]               0.2369      0.262      0.903      0.367      -0.278       0.752
# genre[T.드라마]                -0.0629      0.194     -0.324      0.746      -0.444       0.318
# genre[T.멜로/로맨스]              0.1753      0.229      0.764      0.445      -0.275       0.626
# genre[T.미스터리]                0.1027      0.234      0.439      0.661      -0.356       0.562
# genre[T.범죄]                  0.0578      0.214      0.269      0.788      -0.363       0.479
# genre[T.사극]                  0.2638      0.271      0.972      0.331      -0.269       0.797
# genre[T.스릴러]                 0.2769      0.218      1.272      0.204      -0.150       0.704
# genre[T.애니메이션]               0.2737      0.223      1.229      0.219      -0.164       0.711
# genre[T.액션]                  0.2012      0.191      1.053      0.293      -0.174       0.576
# genre[T.어드벤처]                0.2582      0.241      1.070      0.285      -0.216       0.732
# genre[T.코미디]                 0.1178      0.210      0.561      0.575      -0.295       0.530
# genre[T.판타지]                -0.2179      0.252     -0.866      0.387      -0.712       0.276
# rate[T.15세이상관람가]            -0.0845      0.072     -1.180      0.238      -0.225       0.056
# rate[T.전체관람가]               -0.1629      0.113     -1.442      0.150      -0.385       0.059
# rate[T.청소년관람불가]             -0.0738      0.099     -0.744      0.457      -0.269       0.121
# C(original)[T.1]            -0.0783      0.062     -1.255      0.210      -0.201       0.044
# CAT_running_times[T.B]       0.2240      0.080      2.802      0.005       0.067       0.381
# CAT_running_times[T.C]      -0.1976      0.148     -1.331      0.184      -0.489       0.094
# CAT_expert_rating[T.B]       0.1655      0.095      1.744      0.082      -0.021       0.352
# CAT_expert_rating[T.C]       0.4400      0.117      3.770      0.000       0.211       0.669
# CAT_audience_rating[T.B]    -0.2266      0.197     -1.152      0.250      -0.613       0.159
# CAT_audience_rating[T.C]     0.1289      0.193      0.669      0.503      -0.249       0.507
# scale(screen)                0.9629      0.046     20.984      0.000       0.873       1.053
# scale(rating_audiences)      0.1392      0.037      3.723      0.000       0.066       0.213
# scale(director_power)        0.0345      0.033      1.039      0.299      -0.031       0.100
# scale(actor_power)           0.0605      0.034      1.782      0.075      -0.006       0.127
# ==============================================================================
# Omnibus:                        1.886   Durbin-Watson:                   2.019
# Prob(Omnibus):                  0.390   Jarque-Bera (JB):                1.723
# Skew:                           0.086   Prob(JB):                        0.422
# Kurtosis:                       3.163   Cond. No.                         55.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X_test_CAT_AU = X_test_CAT_Ex.copy()

# %%
X_test_CAT_AU['CAT_audience_rating'] = X_test['audience_rating'].apply(AU_func)

# %%
# model6의 테스트 R
 
pred =  result6.predict(X_test_CAT_AU[['screen', 'CAT_expert_rating', 'CAT_audience_rating', 'CAT_running_times', 'rating_audiences', 'director_power', 'actor_power', 'distributor_group', 'release_season', 'nation', 'genre', 'rate', 'original']])
rss = ((y_test['log_aud'] - pred) ** 2).sum()
tss = ((y_test['log_aud'] - y_test['log_aud'].mean()) ** 2).sum()
rsquared = 1 - rss/tss
rsquared
# Out:
# 0.7744249092056545

# %%
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df6)):
    df_train = df6.iloc[idx_train]
    df_test = df6.iloc[idx_test]
    
    model = sm.OLS.from_formula("log_aud ~" + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred =  result.predict(df_test[['screen', 'CAT_expert_rating', 'CAT_audience_rating', 'CAT_running_times', 'rating_audiences', 'director_power', 'actor_power', 'distributor_group', 'release_season', 'nation', 'genre', 'rate', 'original']])
    rss = ((df_test['log_aud'] - pred) ** 2).sum()
    tss = ((df_test['log_aud'] - df_test['log_aud'].mean()) ** 2).sum()
    rsquared = 1 - rss/tss

    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
# Out:
# 학습 R2 = 0.79726979, 검증 R2 = 0.79304984
# 학습 R2 = 0.80295400, 검증 R2 = 0.73254898
# 학습 R2 = 0.80038510, 검증 R2 = 0.76725580
# 학습 R2 = 0.80043639, 검증 R2 = 0.76755324
# 학습 R2 = 0.80330280, 검증 R2 = 0.74524382
# 학습 R2 = 0.80233628, 검증 R2 = 0.74083740
# 학습 R2 = 0.80140989, 검증 R2 = 0.73796800
# 학습 R2 = 0.79831738, 검증 R2 = 0.78138171
# 학습 R2 = 0.79519138, 검증 R2 = 0.81140424
# 학습 R2 = 0.80037595, 검증 R2 = 0.77266085

# %%
# fig = plt.figure(figsize=(12, 80))
# sm.graphics.plot_partregress_grid(result6, fig=fig)
# fig.suptitle("")
# plt.show()

# %% [markdown]
# # model7
# - df7 : 상호작용 변수 추가하기 전의 데이터프레임
# - 상호작용 독립변수 추가
#     - `director_power*actor_power`

# %%
df7 = df6.copy()

# %%
# df7

feature_names = ['screen', 'rating_audiences', 'director_power', 'actor_power', 'director_power*actor_power']
feature_names = ["scale({})".format(name) for name in feature_names] + ['distributor_group', 'release_season', 'nation', 'genre', 'rate', 'C(original)', 'CAT_running_times', 'CAT_expert_rating', 'CAT_audience_rating']
model7 = sm.OLS.from_formula("log_aud ~" + "+".join(feature_names), data=df7)
result7 = model7.fit()
print(result7.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                log_aud   R-squared:                       0.803
# Model:                            OLS   Adj. R-squared:                  0.791
# Method:                 Least Squares   F-statistic:                
# scale(rating_audiences)                 0.1631      0.038      4.293      0.000       0.088       0.238
# scale(director_power)                   0.1304      0.042      3.104      0.002       0.048       0.213
# scale(actor_power)                      0.1396      0.040      3.484      0.001       0.061       0.218
# scale(before_news)                     -0.0103      0.086     -0.120      0.905      -0.179       0.158
# scale(after_news)                       0.0349      0.092      0.380      0.704      -0.145       0.215
# scale(director_power * actor_power)    -0.1651      0.045     -3.659      0.000      -0.254      -0.076
# ==============================================================================
# Omnibus:                        3.395   Durbin-Watson:                   2.031
# Prob(Omnibus):                  0.183   Jarque-Bera (JB):                3.447
# Skew:                           0.097   Prob(JB):                        0.178
# Kurtosis:                       3.273   Cond. No.                         55.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X_test_inter = X_test_CAT_AU.copy()

# %%
di_ac_inter = []

for index, row in X_test_inter.iterrows():
    di_ac_inter.append(row['director_power'] * row['actor_power'])

# %%
X_test_inter['director_power*actor_power'] = di_ac_inter

# %%
# model7의 테스트 R
 
pred =  result8.predict(X_test_inter[['screen', 'CAT_expert_rating', 'CAT_audience_rating', 'CAT_running_times', 'director_power*actor_power', 'rating_audiences', 'director_power', 'actor_power', 'before_news', 'after_news', 'distributor_group', 'release_season', 'nation', 'genre', 'rate', 'original']])
rss = ((y_test['log_aud'] - pred) ** 2).sum()
tss = ((y_test['log_aud'] - y_test['log_aud'].mean()) ** 2).sum()
rsquared = 1 - rss/tss
rsquared
# Out:
# 0.7744534833419229

# %%
df7_di_ac = df7.copy()

# %%
inter_list = []

for index, row in df7_di_ac.iterrows():
    inter_list.append(row['director_power'] * row['actor_power'])

# %%
df7_di_ac['director_power*actor_power'] = inter_list

# %%
df7_di_ac.columns
# Out:
# Index(['title', 'director', 'distributor', 'distributor_group', 'release_date',
#        'release_season', 'nation', 'screen', 'genre', 'rate', 'expert_rating',
#        'starring_actors', 'running_times', 'audience_rating',
#        'rating_audiences', 'director_power', 'sequel', 'original',
#        'actor_power', 'before_news', 'after_news', 'aud_nationwide', 'log_aud',
#        'CAT_running_times', 'CAT_expert_rating', 'CAT_audience_rating',
#        'director_power*actor_power'],
#       dtype='object')

# %%
from sklearn.model_selection import KFold

scores = np.zeros(15)
cv = KFold(15, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df7_di_ac)):
    df_train = df7_di_ac.iloc[idx_train]
    df_test = df7_di_ac.iloc[idx_test]
    
    model = sm.OLS.from_formula("log_aud ~" + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred =  result.predict(df_test[['screen', 'CAT_expert_rating', 'CAT_audience_rating', 'CAT_running_times', 'director_power*actor_power', 'rating_audiences', 'director_power', 'actor_power', 'before_news', 'after_news', 'distributor_group', 'release_season', 'nation', 'genre', 'rate', 'original']])
    rss = ((df_test['log_aud'] - pred) ** 2).sum()
    tss = ((df_test['log_aud'] - df_test['log_aud'].mean()) ** 2).sum()
    rsquared = 1 - rss/tss

    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
# Out:
# 학습 R2 = 0.80266773, 검증 R2 = 0.78555778
# 학습 R2 = 0.80557402, 검증 R2 = 0.71502457
# 학습 R2 = 0.80181971, 검증 R2 = 0.80356414
# 학습 R2 = 0.80189279, 검증 R2 = 0.79363893
# 학습 R2 = 0.80853745, 검증 R2 = 0.69429321
# 학습 R2 = 0.80281718, 검증 R2 = 0.78075384
# 학습 R2 = 0.81075421, 검증 R2 = 0.66611900
# 학습 R2 = 0.79746206, 검증 R2 = 0.86082251
# 학습 R2 = 0.80710686, 검증 R2 = 0.70541806
# 학습 R2 = 0.80403496, 검증 R2 = 0.75296214
# 학습 R2 = 0.80372512, 검증 R2 = 0.77814566
# 학습 R2 = 0.80722898, 검증 R2 = 0.59809563
# 학습 R2 = 0.80051628, 검증 R2 = 0.81904351
# 학습 R2 = 0.80109187, 검증 R2 = 0.80280312
# 학습 R2 = 0.80395234, 검증 R2 = 0.77120875

# %% [markdown]
# # model8
# - df6 : 상호작용 변수 추가하기 전의 데이터프레임
# - director_power 카테고리화?

# %%
df8 = df6.copy()

# %%
df8 = df8.reset_index(drop=True)

# %%
df8 = df8.reset_index()

# %%
sns.scatterplot(x="director_power", y="aud_nationwide", data=df8)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 8))

index = list(df8['index'])
x_cords = list(df8['director_power'])
y_cords = list(df8['aud_nationwide'])

for i, index in enumerate(index):
    x = x_cords[i]
    y = y_cords[i]
    plt.scatter(x, y, marker='o', color='blue')
    plt.text(x + 0.4, y + 0.4, str(index), fontsize=9)
plt.show()

# %%
df8.iloc[676]
# Out:
# index                          676
# title                         극한직업
# director                       이병헌
# distributor              씨제이이앤엠(주)
# distributor_group                A
# release_date             1/23/2019
# release_season              winter
# nation                          한국
# screen                        1978
# genre                          코미디
# rate                      15세이상관람가
# expert_rating                  6.8
# starring_actors        류승룡,이하늬,진선규
# running_times                  111
# audience_rating            9.34614
# rating_audiences              3279
# director_power         1.15015e+07
# original                         0
# actor_power              358561995
# aud_nationwide            16263360
# CAT_running_times                B
# CAT_expert_rating                B
# CAT_audience_rating              C
# log_aud_nationwide         16.6044
# Name: 676, dtype: object

# %% [markdown]
# # 각각의 독립변수들 하나씩 별개로 OLS

# %%
# # df에서 title을 제외하고 14개의 독립변수 사용

# feature_names = ['screen', 'expert_rating', 'audience_rating', 'running_times', 'rating_audiences', 'director_power', 'actor_power']
# feature_names = ["scale({})".format(name) for name in feature_names] + ['distributor_group', 'release_season', 'nation', 'genre', 'rate', 'C(original)']
# model2 = sm.OLS.from_formula("aud_nationwide ~" + "+".join(feature_names), data=df)
# result2 = model2.fit()
# print(result2.summary())

# %%
model_screen = sm.OLS.from_formula("aud_nationwide ~ scale(screen)", data=df)
result_screen = model_screen.fit()
print(result_screen.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         aud_nationwide   R-squared:                       0.614
# Model:                            OLS   Adj. R-squared:                  0.614
# Method:                 Least Squares   F-statistic:                     940.2
# Date:                Tue, 31 Mar 2020   Prob (F-statistic):          3.30e-124
# Time:                        20:48:54   Log-Likelihood:                -9147.4
# No. Observations:                 592   AIC:                         1.830e+04
# Df Residuals:                     590   BIC:                         1.831e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept      1.071e+06   5.12e+04     20.929      0.000     9.7e+05    1.17e+06
# scale(screen)  1.569e+06   5.12e+04     30.663      0.000    1.47e+06    1.67e+06
# ==============================================================================
# Omnibus:                      448.332   Durbin-Watson:                   2.016
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10655.177
# Skew:                           3.097   Prob(JB):                         0.00
# Kurtosis:                      22.839   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
sns.scatterplot(x="screen", y="aud_nationwide", data=df)
plt.show()

# %%
model_actor_power = sm.OLS.from_formula("aud_nationwide ~ scale(actor_power)", data=df)
result_actor_power = model_actor_power.fit()
print(result_actor_power.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         aud_nationwide   R-squared:                       0.319
# Model:                            OLS   Adj. R-squared:                  0.318
# Method:                 Least Squares   F-statistic:                     276.5
# Date:                Tue, 31 Mar 2020   Prob (F-statistic):           3.32e-51
# Time:                        20:49:24   Log-Likelihood:                -9315.8
# No. Observations:                 592   AIC:                         1.864e+04
# Df Residuals:                     590   BIC:                         1.864e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept           1.071e+06    6.8e+04     15.749      0.000    9.37e+05     1.2e+06
# scale(actor_power)  1.131e+06    6.8e+04     16.629      0.000    9.97e+05    1.26e+06
# ==============================================================================
# Omnibus:                      423.031   Durbin-Watson:                   2.061
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8073.297
# Skew:                           2.925   Prob(JB):                         0.00
# Kurtosis:                      20.119   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
sns.scatterplot(x="actor_power", y="aud_nationwide", data=df)
plt.show()

# %% [markdown]
# ### 모형의 진단과수정

# %%
## 잔차 정규성 확인

sp.stats.probplot(result6.resid, plot=plt)
plt.show()
